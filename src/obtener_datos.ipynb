# %% [markdown]
# # Obtención y migración de datos utiles

# %% [markdown]
# ## Carga de los datos originales

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk

df = pd.read_csv('../data/pois_22-12.csv', sep=';', on_bad_lines='skip')
df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11728\1831428592.py:6: DtypeWarning: Columns (0,3,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/pois_22-12.csv', sep=';', on_bad_lines='skip')
#   id   name  country_latitude country_longitude               city  \
# 0  1  Spain           39.3261          -4.83798              Éibar
# 1  2  Spain           39.3261          -4.83798             Madrid
# 2  3  Spain           39.3261          -4.83798          Barcelona
# 3  4  Spain           39.3261          -4.83798  Palma de Mallorca
# 4  5  Spain           39.3261          -4.83798             Madrid
#
#    city_latitude  city_longitude                                       poi  \
# 0      43.184284       -2.473275  Juan San Martin Eibarko Udal Liburutegia
# 1      40.416705       -3.703582             Biblioteca Nacional de España
# 2      41.382894        2.177432                    Biblioteca de Cataluña
# ...

# %% [markdown]
# # Creación de un dataset puro con unicamente los pois de Barcelona

# %%
df_Barcelona = df[df['city'] == 'Barcelona']
df_Barcelona.shape
# Out:
# (779, 13)

# %% [markdown]
# # Exportación del dataset utile a formato csv

# %%
df_Barcelona.to_csv('../data/pois_barcelona.csv')
