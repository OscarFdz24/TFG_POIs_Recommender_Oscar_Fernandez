# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk

df = pd.read_csv('../data/pois_barcelona_enriched.csv')
df.head()
# Out:
#    Unnamed: 0   id   name  country_latitude  country_longitude       city  \
# 0           2    3  Spain           39.3261           -4.83798  Barcelona
# 1          33   34  Spain           39.3261           -4.83798  Barcelona
# 2          34   35  Spain           39.3261           -4.83798  Barcelona
# 3         110  111  Spain           39.3261           -4.83798  Barcelona
# 4         111  112  Spain           39.3261           -4.83798  Barcelona
#
#    city_latitude  city_longitude                                          poi  \
# 0      41.382894        2.177432                       Biblioteca de Cataluña
# 1      41.382894        2.177432                       Esquerra de l'Eixample
# 2      41.382894        2.177432                      Can Mariner (Barcelona)
# 3      41.382894        2.177432  Archivo Histórico de la Ciudad de Barcelona
# 4      41.382894        2.177432                   Arxiu Diocesà de Barcelona
#
#    poi_latitude  ...           value_en  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'country_latitude', 'country_longitude',
#        'city', 'city_latitude', 'city_longitude', 'poi', 'poi_latitude',
#        'poi_longitude', 'category', 'subcategory', 'value_en', 'horario',
#        'presupuesto_eur_min', 'presupuesto_eur_max', 'aforo_estimado_personas',
#        'reserva_recomendada', 'metodo_dato', 'fuente_url', 'confianza',
#        'fecha_revision'],
#       dtype='object')

# %%
print(f'Metodologia de datos: {df['metodo_dato'].unique()}')
print('-----------')
print(f'Fuente: {df['fuente_url'].unique()}')
print('-----------')
print(f'Categorias: {df['category'].unique()}')
print('-----------')
print(f'Horarios: {df['horario'].unique()}')
print('-----------')
print(f'Reservas: {df['reserva_recomendada'].unique()}')
# Out:
# Metodologia de datos: ['heuristic' 'web+estimación']
# -----------
# Fuente: [nan
#  'https://parkguell.barcelona/es/planifica-la-visita/tarifas-y-horarios'
#  'https://www.lapedrera.com/es/entradas/ ; https://www.lapedrera.com/es/informacion-practica/'
#  'https://www.casabatllo.es/venta-entradas/'
#  'https://www.fcbarcelona.es/es/entradas/camp-nou-experience ; https://www.fcbarcelona.es/es/entradas/camp-nou-experience/informacion-util'
#  'https://sagradafamilia.org/es/horarios-como-llegar ; https://sagradafamilia.org/es/tickets-individuals'
#  'https://museupicassobcn.cat/es/planifica-la-visita/horarios-y-precios']
# -----------
# Categorias: ['Cultural' 'Parque' 'Fuente' 'Punto de interés' 'Histórico' 'Monumento'
#  'Puente' 'Religioso' 'Administrativo' nan]
# -----------
# Horarios: ['L-V 09:00-20:00; S 10:00-14:00 (varía)' 'Variable'
#  'Enero (ej.): apertura 09:30; última hora de acceso 17:30; cierre aprox. 18:00 (varía por fecha)'
# ...
